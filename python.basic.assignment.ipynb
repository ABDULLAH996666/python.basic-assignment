# %% [markdown]
# # PHYTHON BASICS ASSIGNMENT
# TOPICS:
# * print()
# * variables
# * data types
# * Arithmetic opertors
# * logic opertors

# %%
# Q1 student information

name = "Abdullah" 
age = 17 
city = "karachi"
status = "second year CS student"

print(name)
print(age)
print(city)
print(status)
# Out:
# Abdullah
# 17
# karachi
# second year CS student

# %%
# Q2 Data types

name = "abdullah"
age = 17 
height = 5.4
student = True

print(name)
print(type(name))
print(age)
print(type(age))
print(height)
print(type(height))
print(student)
print(type(student))
# Out:
# abdullah
# <class 'str'>
# 17
# <class 'int'>
# 5.4
# <class 'float'>
# True
# <class 'bool'>

# %%
# Q3 Arthimetic operation 

num1 = 23
num2 = 6
num3 = 56
num4 = 43
num5 = 12
num6 = 3

print(num1+num2)
print(num3-num4)
print(num5*num6)
print(num1/num2)
print(num3%num4)
print(num5**num6)
# Out:
# 29
# 13
# 36
# 3.8333333333333335
# 13
# 1728

# %%
# Q4 student marks calculator 

maths = 87
physics = 69
computer = 91

total = maths+physics+computer

print(total) 
print(total/3)
# Out:
# 247
# 82.33333333333333

# %%
# Q5 calculate shoping bill

price = 450
quantity = 7

print(price*quantity)
# Out:
# 3150

# %%
# Q6 Reactangle area

length = 6.7
width = 5.3

area = length * width
perimeter = 2 * (length + width)

print(area)
print(perimeter)
# Out:
# 35.51
# 24.0

# %%
# Q7 Time converter

minutes = 250
hours = minutes // 60
remaining_minuts = minutes % 60

print(hours)
print(remaining_minuts)
# Out:
# 4
# 10

# %%
# Q8 student eligiblity

marks = 76
attandance = 88

eligible = marks >= 50 and attandance >= 75 

print(eligible)
# Out:
# True

# %%
# Q9 logic operoter

a = True
b = False

print(a and b)
print (a or b)
print(not a)
print(not b)
# Out:
# False
# True
# False
# True

# %%
# Final challange. (student report)\

student_name = "Abdullah"
age = 17 

maths = 76
physic = 56
computer = 86

attandance = 79

total_marks = maths + physic + computer 

average_marks = total_marks/3

eligible = average_marks >= 50 and attandance >= 75

print(student_name)
print(age)
print(maths)
print(physic)
print(computer)
print(attandance)
print(total_marks)
print (average_marks)
print(eligible)
# Out:
# Abdullah
# 17
# 76
# 56
# 86
# 79
# 218
# 72.66666666666667
# True
